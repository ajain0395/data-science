# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.dates
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
filename = "./data/microsoft_stockData.csv"

# %%
data = pd.read_csv(filename)

# %%
data.head()
# Out:
#     timestamp    open    high     low   close    volume
# 0    1/2/2019   99.55  101.75   98.94  101.12  35329345
# 1  12/31/2018  101.29  102.40  100.44  101.57  33173765
# 2  12/28/2018  102.09  102.41   99.52  100.39  38169312
# 3  12/27/2018   99.30  101.19   96.40  101.18  49498509
# 4  12/26/2018   95.14  100.69   93.96  100.56  51634793

# %%
dateheader = 'timestamp'

# %%
x = data[dateheader]

# %%
date_objects = [datetime.strptime(x, '%m/%d/%Y').date() for x in x]

# %%
def subplot_(X,Y,i,j,title,xlabel,ylabel,label,ax_arr,color='b'):
    ax_arr[i,j].plot(X, Y, color, label = label)
# ax_arr[0,i]jplot([0, 1], [0, 1],'r--')
    ax_arr[i,j].set_title(title,fontsize=20)
    ax_arr[i,j].set_ylabel(ylabel,fontsize=20)
    ax_arr[i,j].set_xlabel(xlabel,fontsize=15)
    ax_arr[i,j].legend(loc = 'best', prop={'size': 16})
#     return ax_arr

# %%
list(set(data.columns).difference(set(dateheader)))
# Out:
# ['high', 'low', 'close', 'timestamp', 'volume', 'open']

# %%
headings = []
for i in data.columns:
    if i != dateheader:
        headings.append(i)

# %%
data.columns
# Out:
# Index(['timestamp', 'open', 'high', 'low', 'close', 'volume'], dtype='object')

# %%
# headings = ['Close', 'Adj Close', 'High', 'Volume', 'Low', 'Open']
index = 0
colors = ['yellow','cyan','blue','green','red','brown']
fig, ax_arr = plt.subplots(nrows = 2, ncols = 3, figsize = (20,15))
for row in range(0,2):
    for col in range(0,3):
        subplot_(X=date_objects,Y=data[headings[index]],i=row,j=col,title="Time vs " +headings[index],
                 xlabel="Date",ylabel=headings[index],label=headings[index],ax_arr=ax_arr,color=colors[index])
        index+=1
        if(index >= len(headings)):
            break
    if(index >= len(headings)):
        break
plt.subplots_adjust(wspace=0.2)
plt.tight_layout()

# %%
from pandas.plotting import lag_plot,autocorrelation_plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
data_2 = pd.read_csv(filename,header=0,index_col=0)

# %%
# lag_plot(data_2)

# %%
# autocorrelation_plot(data_2)

# %%
# data_2.columns

# %%
from statsmodels.tsa.stattools import kpss

for i in headings:
        print("Testing for the feature : "+str(i))
        X = data_2[i]
        test = kpss(X)
        output = pd.Series(test[0:3], index=['Test Statistic','p-value','Number of Lags Used'])
        for key,value in test[3].items():
            output['critical value (%s)'%key] = value
        print (output)
# Out:
# Testing for the feature : open
# Test Statistic            3.52312
# p-value                   0.01000
# Number of Lags Used      33.00000
# critical value (10%)      0.34700
# critical value (5%)       0.46300
# critical value (2.5%)     0.57400
# critical value (1%)       0.73900
# dtype: float64
# Testing for the feature : high
# Test Statistic            3.553926
# p-value                   0.010000
# Number of Lags Used      33.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : low
# Test Statistic            3.498591
# p-value                   0.010000
# Number of Lags Used      33.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : close
# Test Statistic            3.524548
# p-value                   0.010000
# Number of Lags Used      33.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : volume
# Test Statistic            2.920787
# p-value                   0.010000
# Number of Lags Used      33.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64

# %%
from statsmodels.tsa.arima_model import ARMA

def arma_model_fit(X):
    model = ARMA(X,order =(7,1))
    model_fit = model.fit(disp=0)
    print(model_fit.summary())
    forecast = model_fit.forecast(steps=7)[0]
    for i in range(len(forecast)):
        print('Day %d: %f' % ((i+1), forecast[i]))    
    
for i in headings:
        print("Model fit and forecast : "+str(i))
#         model_fit = 
        arma_model_fit(data_2[i])
        print ("Predictability of %s values for next 7 days : " % str(i))
#         forecast(model_fit)
# Out:
# Model fit and forecast : open
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   open   No. Observations:                 5284
# Model:                     ARMA(7, 1)   Log Likelihood              -11324.126
# Method:                       css-mle   S.D. of innovations              2.062
# Date:                Mon, 28 Oct 2019   AIC                          22668.252
# Time:                        22:12:18   BIC                          22733.976
# Sample:                             0   HQIC                         22691.223
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         61.8354     16.609      3.723      0.000      29.282      94.389
# ar.L1.open     1.5238      0.050     30.312      0.000       1.425       1.622
# ar.L2.open    -0.5131      0.050    -10.363      0.000      -0.610      -0.416
# ar.L3.open     0.0398      0.026      1.523      0.128      -0.011       0.091
# ar.L4.open    -0.0744      0.026     -2.838      0.005      -0.126      -0.023
# ar.L5.open     0.0211      0.026      0.808      0.419      -0.030       0.072
# ar.L6.open     0.0125      0.025      0.496      0.620      -0.037       0.062
# ar.L7.open    -0.0104      0.014     -0.755      0.450      -0.037       0.017
# ma.L1.open    -0.5930      0.052    -11.400      0.000      -0.695      -0.491
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0016           -0.0000j            1.0016           -0.0000
# AR.2           -2.7384           -0.0000j            2.7384           -0.5000
# AR.3           -0.9159           -1.9217j            2.1288           -0.3208
# AR.4           -0.9159           +1.9217j            2.1288            0.3208
# AR.5            1.5259           -0.0000j            1.5259           -0.0000
# AR.6            1.6200           -1.5628j            2.2510           -0.1221
# AR.7            1.6200           +1.5628j            2.2510            0.1221
# MA.1            1.6864           +0.0000j            1.6864            0.0000
# -----------------------------------------------------------------------------
# Day 1: 129.594946
# Day 2: 129.575528
# Day 3: 129.415483
# Day 4: 129.317715
# Day 5: 129.238557
# Day 6: 129.126635
# Day 7: 129.020723
# Predictability of open values for next 7 days :
# Model fit and forecast : high
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   high   No. Observations:                 5284
# Model:                     ARMA(7, 1)   Log Likelihood              -10971.297
# Method:                       css-mle   S.D. of innovations              1.929
# Date:                Mon, 28 Oct 2019   AIC                          21962.594
# Time:                        22:12:25   BIC                          22028.318
# Sample:                             0   HQIC                         21985.565
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         62.9171     17.112      3.677      0.000      29.378      96.456
# ar.L1.high     1.4767      0.081     18.178      0.000       1.317       1.636
# ar.L2.high    -0.5437      0.085     -6.382      0.000      -0.711      -0.377
# ar.L3.high     0.1128      0.026      4.302      0.000       0.061       0.164
# ar.L4.high    -0.0576      0.026     -2.185      0.029      -0.109      -0.006
# ar.L5.high     0.0205      0.026      0.797      0.426      -0.030       0.071
# ar.L6.high    -0.0069      0.025     -0.281      0.779      -0.055       0.041
# ar.L7.high    -0.0025      0.014     -0.181      0.856      -0.030       0.025
# ma.L1.high    -0.4442      0.082     -5.392      0.000      -0.606      -0.283
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2            1.7440           -0.0000j            1.7440           -0.0000
# AR.3            1.3665           -2.0006j            2.4227           -0.1546
# AR.4            1.3665           +2.0006j            2.4227            0.1546
# AR.5           -1.3317           -2.2827j            2.6427           -0.3341
# AR.6           -1.3317           +2.2827j            2.6427            0.3341
# AR.7           -5.5716           -0.0000j            5.5716           -0.5000
# MA.1            2.2511           +0.0000j            2.2511            0.0000
# -----------------------------------------------------------------------------
# Day 1: 131.345130
# Day 2: 131.358049
# Day 3: 131.226843
# Day 4: 131.134041
# Day 5: 131.026192
# Day 6: 130.911821
# Day 7: 130.805340
# Predictability of high values for next 7 days :
# Model fit and forecast : low
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                    low   No. Observations:                 5284
# Model:                     ARMA(7, 1)   Log Likelihood              -11072.907
# Method:                       css-mle   S.D. of innovations              1.966
# Date:                Mon, 28 Oct 2019   AIC                          22165.815
# Time:                        22:12:34   BIC                          22231.539
# Sample:                             0   HQIC                         22188.786
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         61.1760     16.422      3.725      0.000      28.989      93.363
# ar.L1.low      1.5409      0.061     25.281      0.000       1.421       1.660
# ar.L2.low     -0.5869      0.063     -9.308      0.000      -0.710      -0.463
# ar.L3.low      0.0713      0.026      2.700      0.007       0.020       0.123
# ar.L4.low     -0.0065      0.027     -0.244      0.807      -0.059       0.046
# ar.L5.low     -0.0372      0.027     -1.399      0.162      -0.089       0.015
# ar.L6.low      0.0283      0.025      1.117      0.264      -0.021       0.078
# ar.L7.low     -0.0107      0.014     -0.773      0.439      -0.038       0.016
# ma.L1.low     -0.5386      0.062     -8.625      0.000      -0.661      -0.416
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0016           -0.0000j            1.0016           -0.0000
# AR.2           -2.2218           -0.0000j            2.2218           -0.5000
# AR.3           -0.5230           -2.1062j            2.1702           -0.2887
# AR.4           -0.5230           +2.1062j            2.1702            0.2887
# AR.5            1.6183           -0.0000j            1.6183           -0.0000
# AR.6            1.6512           -1.6756j            2.3525           -0.1262
# AR.7            1.6512           +1.6756j            2.3525            0.1262
# MA.1            1.8566           +0.0000j            1.8566            0.0000
# -----------------------------------------------------------------------------
# Day 1: 129.443492
# Day 2: 129.305151
# Day 3: 129.167917
# Day 4: 129.123760
# Day 5: 129.008531
# Day 6: 128.910907
# Day 7: 128.812023
# Predictability of low values for next 7 days :
# Model fit and forecast : close
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 5284
# Model:                     ARMA(7, 1)   Log Likelihood              -11227.605
# Method:                       css-mle   S.D. of innovations              2.025
# Date:                Mon, 28 Oct 2019   AIC                          22475.209
# Time:                        22:12:47   BIC                          22540.934
# Sample:                             0   HQIC                         22498.180
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          62.3791     17.019      3.665      0.000      29.022      95.736
# ar.L1.close     0.2877      0.257      1.118      0.263      -0.217       0.792
# ar.L2.close     0.6752      0.254      2.657      0.008       0.177       1.173
# ar.L3.close    -0.0224      0.018     -1.279      0.201      -0.057       0.012
# ar.L4.close     0.0495      0.017      2.856      0.004       0.016       0.084
# ar.L5.close     0.0388      0.023      1.699      0.089      -0.006       0.084
# ar.L6.close    -0.0045      0.015     -0.294      0.769      -0.035       0.026
# ar.L7.close    -0.0269      0.014     -1.953      0.051      -0.054       0.000
# ma.L1.close     0.6994      0.257      2.721      0.007       0.196       1.203
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           -0.0000j            1.0015           -0.0000
# AR.2            2.0613           -0.0000j            2.0613           -0.0000
# AR.3            0.5773           -1.7623j            1.8544           -0.1996
# AR.4            0.5773           +1.7623j            1.8544            0.1996
# AR.5           -1.3169           -0.0000j            1.3169           -0.5000
# AR.6           -1.5342           -1.2725j            1.9932           -0.3898
# AR.7           -1.5342           +1.2725j            1.9932            0.3898
# MA.1           -1.4297           +0.0000j            1.4297            0.5000
# -----------------------------------------------------------------------------
# Day 1: 131.022474
# Day 2: 130.986483
# Day 3: 130.820484
# Day 4: 130.777096
# Day 5: 130.638236
# Day 6: 130.583564
# Day 7: 130.445728
# Predictability of close values for next 7 days :
# Model fit and forecast : volume
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 volume   No. Observations:                 5284
# Model:                     ARMA(7, 1)   Log Likelihood              -96267.527
# Method:                       css-mle   S.D. of innovations       19767450.315
# Date:                Mon, 28 Oct 2019   AIC                         192555.054
# Time:                        22:12:58   BIC                         192620.778
# Sample:                             0   HQIC                        192578.025
#
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         4.754e+07   1.23e+07      3.861      0.000    2.34e+07    7.17e+07
# ar.L1.volume     1.3793      0.010    137.391      0.000       1.360       1.399
# ar.L2.volume    -0.3025      0.019    -15.908      0.000      -0.340      -0.265
# ar.L3.volume    -0.0196      0.023     -0.840      0.401      -0.065       0.026
# ar.L4.volume    -0.0279      0.024     -1.171      0.241      -0.074       0.019
# ar.L5.volume     0.0108      0.024      0.455      0.649      -0.036       0.057
# ar.L6.volume    -0.0328      0.023     -1.399      0.162      -0.079       0.013
# ar.L7.volume    -0.0076      0.014     -0.544      0.587      -0.035       0.020
# ma.L1.volume    -0.9831      0.004   -253.612      0.000      -0.991      -0.976
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0008           -0.0000j            1.0008           -0.0000
# AR.2            1.2875           -0.0000j            1.2875           -0.0000
# AR.3            0.7974           -1.7869j            1.9567           -0.1832
# AR.4            0.7974           +1.7869j            1.9567            0.1832
# AR.5           -1.6564           -1.6465j            2.3355           -0.3755
# AR.6           -1.6564           +1.6465j            2.3355            0.3755
# AR.7           -4.8597           -0.0000j            4.8597           -0.5000
# MA.1            1.0172           +0.0000j            1.0172            0.0000
# -----------------------------------------------------------------------------
# Day 1: 9285940.768186
# Day 2: 10569095.122385
# Day 3: 11172468.600843
# Day 4: 11679840.191850
# Day 5: 11939343.020818
# Day 6: 12297486.545535
# Day 7: 12597317.977434
# Predictability of volume values for next 7 days :

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
lags = 100
for i in headings:
    plot_acf(data_2[i],title=i+ " acf",lags=lags)

# %%
# from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
for i in headings:
    plot_pacf(data_2[i],title=i + " pacf",lags=lags)
