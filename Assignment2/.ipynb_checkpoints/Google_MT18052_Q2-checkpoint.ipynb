# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.dates
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
filename = "./data/google_stock.csv"

# %%
data = pd.read_csv(filename)

# %%
data.head()

# %%
x = data.Date

# %%
date_objects = [datetime.strptime(x, '%m/%d/%Y').date() for x in x]

# %%
def subplot_(X,Y,i,j,title,xlabel,ylabel,label,ax_arr,color='b'):
    ax_arr[i,j].plot(X, Y, color, label = label)
# ax_arr[0,i]jplot([0, 1], [0, 1],'r--')
    ax_arr[i,j].set_title(title,fontsize=20)
    ax_arr[i,j].set_ylabel(ylabel,fontsize=20)
    ax_arr[i,j].set_xlabel(xlabel,fontsize=15)
    ax_arr[i,j].legend(loc = 'best', prop={'size': 16})
#     return ax_arr

# %%
list(set(data.columns).difference(set('Date')))

# %%
headings = []
for i in data.columns:
    if i != 'Date':
        headings.append(i)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# headings = ['Close', 'Adj Close', 'High', 'Volume', 'Low', 'Open']
index = 0
colors = ['yellow','cyan','blue','green','red','brown']
fig, ax_arr = plt.subplots(nrows = 2, ncols = 3, figsize = (20,15))
for row in range(0,2):
    for col in range(0,3):
        subplot_(X=date_objects,Y=data[headings[index]],i=row,j=col,title="Time vs " +headings[index],
                 xlabel="Date",ylabel=headings[index],label=headings[index],ax_arr=ax_arr,color=colors[index])
        index+=1
plt.subplots_adjust(wspace=0.2)
plt.tight_layout()

# %%
from pandas.plotting import lag_plot,autocorrelation_plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
data_2 = pd.read_csv(filename,header=0,index_col=0)

# %%
# lag_plot(data_2)

# %%
# autocorrelation_plot(data_2)

# %%
# data_2.columns

# %%
from statsmodels.tsa.stattools import kpss

for i in headings:
        print("Testing for the feature : "+str(i))
        X = data_2[i]
        test = kpss(X)
        output = pd.Series(test[0:3], index=['Test Statistic','p-value','Number of Lags Used'])
        for key,value in test[3].items():
            output['critical value (%s)'%key] = value
        print (output)
# Out:
# Testing for the feature : Open
# Test Statistic            4.857621
# p-value                   0.010000
# Number of Lags Used      23.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : High
# Test Statistic            4.858573
# p-value                   0.010000
# Number of Lags Used      23.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : Low
# Test Statistic            4.860304
# p-value                   0.010000
# Number of Lags Used      23.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : Close
# Test Statistic            4.859777
# p-value                   0.010000
# Number of Lags Used      23.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : Adj Close
# Test Statistic            4.859777
# p-value                   0.010000
# Number of Lags Used      23.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64
# Testing for the feature : Volume
# Test Statistic            3.276263
# p-value                   0.010000
# Number of Lags Used      23.000000
# critical value (10%)      0.347000
# critical value (5%)       0.463000
# critical value (2.5%)     0.574000
# critical value (1%)       0.739000
# dtype: float64

# %%
from statsmodels.tsa.arima_model import ARMA

def arma_model_fit(X):
    model = ARMA(X,order =(7,1))
    model_fit = model.fit(disp=0)
    print(model_fit.summary())
    forecast = model_fit.forecast(steps=7)[0]
    for i in range(len(forecast)):
        print('Day %d: %f' % ((i+1), forecast[i]))    
    
for i in headings:
        print("Model fit and forecast : "+str(i))
#         model_fit = 
        arma_model_fit(data_2[i])
        print ("Predictability of %s values for next 7 days : " % str(i))
#         forecast(model_fit)
# Out:
# Model fit and forecast : Open
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   Open   No. Observations:                 1259
# Model:                     ARMA(7, 1)   Log Likelihood               -4561.485
# Method:                       css-mle   S.D. of innovations              9.037
# Date:                Mon, 28 Oct 2019   AIC                           9142.971
# Time:                        22:09:28   BIC                           9194.351
# Sample:                             0   HQIC                          9162.280
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        687.0497    271.476      2.531      0.012     154.966    1219.133
# ar.L1.Open     1.1153      0.019     58.824      0.000       1.078       1.152
# ar.L2.Open    -0.0997      0.034     -2.932      0.003      -0.166      -0.033
# ar.L3.Open    -0.0135      0.042     -0.318      0.750      -0.096       0.069
# ar.L4.Open    -0.0692      0.042     -1.640      0.101      -0.152       0.014
# ar.L5.Open     0.0400      0.042      0.947      0.344      -0.043       0.123
# ar.L6.Open     0.0375      0.042      0.889      0.374      -0.045       0.120
# ar.L7.Open    -0.0107      0.028     -0.381      0.703      -0.066       0.044
# ma.L1.Open    -0.1307      0.034     -3.847      0.000      -0.197      -0.064
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0004           -0.0000j            1.0004           -0.0000
# AR.2           -0.9371           -1.5980j            1.8525           -0.3344
# AR.3           -0.9371           +1.5980j            1.8525            0.3344
# AR.4           -2.2456           -0.0000j            2.2456           -0.5000
# AR.5            1.2857           -1.1572j            1.7298           -0.1166
# AR.6            1.2857           +1.1572j            1.7298            0.1166
# AR.7            4.0361           -0.0000j            4.0361           -0.0000
# MA.1            7.6525           +0.0000j            7.6525            0.0000
# -----------------------------------------------------------------------------
# Day 1: 1046.854713
# Day 2: 1046.734728
# Day 3: 1046.954079
# Day 4: 1047.322282
# Day 5: 1047.298671
# Day 6: 1047.125740
# Day 7: 1046.967753
# Predictability of Open values for next 7 days :
# Model fit and forecast : High
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                   High   No. Observations:                 1259
# Model:                     ARMA(7, 1)   Log Likelihood               -4442.800
# Method:                       css-mle   S.D. of innovations              8.215
# Date:                Mon, 28 Oct 2019   AIC                           8905.600
# Time:                        22:09:40   BIC                           8956.981
# Sample:                             0   HQIC                          8924.909
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1751.5271        nan        nan        nan         nan         nan
# ar.L1.High     0.1320        nan        nan        nan         nan         nan
# ar.L2.High     0.9399        nan        nan        nan         nan         nan
# ar.L3.High    -0.1251      0.005    -25.645      0.000      -0.135      -0.116
# ar.L4.High     0.0044      0.036      0.124      0.901      -0.065       0.074
# ar.L5.High     0.0043      0.032      0.133      0.894      -0.058       0.067
# ar.L6.High     0.0330      0.031      1.070      0.285      -0.027       0.094
# ar.L7.High     0.0114      0.027      0.420      0.675      -0.042       0.065
# ma.L1.High     0.9793      0.017     55.984      0.000       0.945       1.014
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0000           -0.0000j            1.0000           -0.0000
# AR.2           -1.0199           -0.0000j            1.0199           -0.5000
# AR.3            1.4500           -1.3252j            1.9644           -0.1178
# AR.4            1.4500           +1.3252j            1.9644            0.1178
# AR.5           -1.1212           -2.2461j            2.5103           -0.3237
# AR.6           -1.1212           +2.2461j            2.5103            0.3237
# AR.7           -3.5309           -0.0000j            3.5309           -0.5000
# MA.1           -1.0212           +0.0000j            1.0212            0.5000
# -----------------------------------------------------------------------------
# Day 1: 1049.551923
# Day 2: 1049.867505
# Day 3: 1050.185065
# Day 4: 1050.399983
# Day 5: 1050.525646
# Day 6: 1050.497112
# Day 7: 1050.524759
# Predictability of High values for next 7 days :
# Model fit and forecast : Low
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                    Low   No. Observations:                 1259
# Model:                     ARMA(7, 1)   Log Likelihood               -4427.305
# Method:                       css-mle   S.D. of innovations              8.123
# Date:                Mon, 28 Oct 2019   AIC                           8874.611
# Time:                        22:09:43   BIC                           8925.991
# Sample:                             0   HQIC                          8893.920
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        647.5605    278.365      2.326      0.020     101.974    1193.147
# ar.L1.Low      1.2853      0.013     96.451      0.000       1.259       1.311
# ar.L2.Low     -0.3183      0.029    -10.873      0.000      -0.376      -0.261
# ar.L3.Low      0.0090      0.043      0.209      0.834      -0.075       0.093
# ar.L4.Low     -0.0130      0.047     -0.280      0.780      -0.104       0.078
# ar.L5.Low     -0.0009      0.047     -0.018      0.985      -0.092       0.091
# ar.L6.Low      0.0584      0.046      1.274      0.203      -0.031       0.148
# ar.L7.Low     -0.0208      0.028     -0.739      0.460      -0.076       0.034
# ma.L1.Low     -0.1462      0.031     -4.700      0.000      -0.207      -0.085
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0004           -0.0000j            1.0004           -0.0000
# AR.2           -1.9152           -0.0000j            1.9152           -0.5000
# AR.3           -0.7089           -1.6793j            1.8228           -0.3136
# AR.4           -0.7089           +1.6793j            1.8228            0.3136
# AR.5            1.1976           -1.1483j            1.6592           -0.1217
# AR.6            1.1976           +1.1483j            1.6592            0.1217
# AR.7            2.7437           -0.0000j            2.7437           -0.0000
# MA.1            6.8396           +0.0000j            6.8396            0.0000
# -----------------------------------------------------------------------------
# Day 1: 1045.342403
# Day 2: 1045.793148
# Day 3: 1045.787094
# Day 4: 1045.707658
# Day 5: 1045.458955
# Day 6: 1045.234084
# Day 7: 1045.046307
# Predictability of Low values for next 7 days :
# Model fit and forecast : Close
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 1259
# Model:                     ARMA(7, 1)   Log Likelihood               -4521.358
# Method:                       css-mle   S.D. of innovations              8.744
# Date:                Mon, 28 Oct 2019   AIC                           9062.716
# Time:                        22:09:46   BIC                           9114.097
# Sample:                             0   HQIC                          9082.025
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1809.2738        nan        nan        nan         nan         nan
# ar.L1.Close     0.2280        nan        nan        nan         nan         nan
# ar.L2.Close     0.8059        nan        nan        nan         nan         nan
# ar.L3.Close    -0.0640      0.031     -2.031      0.043      -0.126      -0.002
# ar.L4.Close    -0.0359      0.032     -1.113      0.266      -0.099       0.027
# ar.L5.Close     0.0166      0.037      0.452      0.651      -0.055       0.089
# ar.L6.Close     0.0161      0.029      0.559      0.576      -0.040       0.072
# ar.L7.Close     0.0333      0.028      1.181      0.238      -0.022       0.089
# ma.L1.Close     0.8063      0.022     36.971      0.000       0.764       0.849
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0000           -0.0000j            1.0000           -0.0000
# AR.2            1.3607           -1.1315j            1.7697           -0.1104
# AR.3            1.3607           +1.1315j            1.7697            0.1104
# AR.4           -1.4738           -0.0327j            1.4742           -0.4965
# AR.5           -1.4738           +0.0327j            1.4742            0.4965
# AR.6           -0.6281           -2.0049j            2.1010           -0.2983
# AR.7           -0.6281           +2.0049j            2.1010            0.2983
# MA.1           -1.2402           +0.0000j            1.2402            0.5000
# -----------------------------------------------------------------------------
# Day 1: 1046.873169
# Day 2: 1047.292118
# Day 3: 1047.630782
# Day 4: 1047.826518
# Day 5: 1047.806325
# Day 6: 1047.861748
# Day 7: 1047.790085
# Predictability of Close values for next 7 days :
# Model fit and forecast : Adj Close
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:              Adj Close   No. Observations:                 1259
# Model:                     ARMA(7, 1)   Log Likelihood               -4521.358
# Method:                       css-mle   S.D. of innovations              8.744
# Date:                Mon, 28 Oct 2019   AIC                           9062.716
# Time:                        22:09:49   BIC                           9114.097
# Sample:                             0   HQIC                          9082.025
#
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const            1809.2738        nan        nan        nan         nan         nan
# ar.L1.Adj Close     0.2280        nan        nan        nan         nan         nan
# ar.L2.Adj Close     0.8059        nan        nan        nan         nan         nan
# ar.L3.Adj Close    -0.0640      0.031     -2.031      0.043      -0.126      -0.002
# ar.L4.Adj Close    -0.0359      0.032     -1.113      0.266      -0.099       0.027
# ar.L5.Adj Close     0.0166      0.037      0.452      0.651      -0.055       0.089
# ar.L6.Adj Close     0.0161      0.029      0.559      0.576      -0.040       0.072
# ar.L7.Adj Close     0.0333      0.028      1.181      0.238      -0.022       0.089
# ma.L1.Adj Close     0.8063      0.022     36.971      0.000       0.764       0.849
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0000           -0.0000j            1.0000           -0.0000
# AR.2            1.3607           -1.1315j            1.7697           -0.1104
# AR.3            1.3607           +1.1315j            1.7697            0.1104
# AR.4           -1.4738           -0.0327j            1.4742           -0.4965
# AR.5           -1.4738           +0.0327j            1.4742            0.4965
# AR.6           -0.6281           -2.0049j            2.1010           -0.2983
# AR.7           -0.6281           +2.0049j            2.1010            0.2983
# MA.1           -1.2402           +0.0000j            1.2402            0.5000
# -----------------------------------------------------------------------------
# Day 1: 1046.873169
# Day 2: 1047.292118
# Day 3: 1047.630782
# Day 4: 1047.826518
# Day 5: 1047.806325
# Day 6: 1047.861748
# Day 7: 1047.790085
# Predictability of Adj Close values for next 7 days :
# Model fit and forecast : Volume
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                 Volume   No. Observations:                 1259
# Model:                     ARMA(7, 1)   Log Likelihood              -19298.518
# Method:                       css-mle   S.D. of innovations        1097575.163
# Date:                Mon, 28 Oct 2019   AIC                          38617.036
# Time:                        22:09:52   BIC                          38668.417
# Sample:                             0   HQIC                         38636.345
#
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         2.415e+06   1.11e+06      2.178      0.030    2.42e+05    4.59e+06
# ar.L1.Volume     1.5314      0.027     57.613      0.000       1.479       1.584
# ar.L2.Volume    -0.6187      0.047    -13.194      0.000      -0.711      -0.527
# ar.L3.Volume     0.1507      0.053      2.857      0.004       0.047       0.254
# ar.L4.Volume    -0.0665      0.054     -1.224      0.221      -0.173       0.040
# ar.L5.Volume     0.0403      0.054      0.741      0.459      -0.066       0.147
# ar.L6.Volume    -0.0668      0.052     -1.294      0.196      -0.168       0.034
# ar.L7.Volume     0.0288      0.029      0.990      0.322      -0.028       0.086
# ma.L1.Volume    -0.9664      0.011    -86.244      0.000      -0.988      -0.944
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0014           -0.0000j            1.0014           -0.0000
# AR.2           -1.4614           -1.1945j            1.8875           -0.3909
# AR.3           -1.4614           +1.1945j            1.8875            0.3909
# AR.4            0.3847           -1.7170j            1.7595           -0.2149
# AR.5            0.3847           +1.7170j            1.7595            0.2149
# AR.6            1.7336           -0.3646j            1.7715           -0.0330
# AR.7            1.7336           +0.3646j            1.7715            0.0330
# MA.1            1.0348           +0.0000j            1.0348            0.0000
# -----------------------------------------------------------------------------
# Day 1: 1144596.929736
# Day 2: 1255970.727256
# Day 3: 1317286.479080
# Day 4: 1326155.476869
# Day 5: 1347309.908579
# Day 6: 1370507.654674
# Day 7: 1378975.614341
# Predictability of Volume values for next 7 days :

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
lags = 100
for i in headings:
    plot_acf(data_2[i],title=i+ " acf",lags=lags)

# %%
# from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
for i in headings:
    plot_pacf(data_2[i],title=i + " pacf",lags=lags)
