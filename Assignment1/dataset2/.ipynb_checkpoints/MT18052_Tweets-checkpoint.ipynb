# %%
import sys
print(sys.executable)
# Out:
# /home/ashish/anaconda3/bin/python

# %%
import numpy as np
from wordcloud import WordCloud as wcl
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns

# %%
df = pd.read_csv(r"1377884570_tweet_global_warming.csv", encoding ="latin-1")

# %%
df.tail()
# Out:
#                                                   tweet existence confidence  \
# 6053  That's why he removed the data that disagreed ...        No     0.6718
# 6056  Climate Change Fraud - Global warming: It has ...        No          1
# 6087  Global warming you tube parody you will enjoy ...        No     0.6411
# 6088  One-Eyed Golfer: Don't dare tell me about glob...        No          1
# 6089  man made global warming a hair brained theory ...        No          1
#
#      other1 other2  other3
# 6053    NaN    NaN     NaN
# 6056    NaN    NaN     NaN
# 6087    NaN    NaN     NaN
# 6088    NaN    NaN     NaN
# 6089    NaN    NaN     NaN

# %%
df=df.replace(to_replace ="Y", value ="Yes")

# %%
df=df.replace(to_replace ="N", value ="No")

# %%
y1 = df[df.existence == 'Yes']

# %%
n1 = df[df.existence =='No']

# %%
n2 = df[df.existence =='NA']

# %%
y1.tail()
# Out:
#                                                   tweet existence confidence  \
# 6080  Bats, Birds and Lizards Can Fight Climate Chan...       Yes     0.6751
# 6081  Bats, Birds and Lizards Can Fight Climate Chan...       Yes          1
# 6082  Global warming: The fossil fuel dilemma: Ameri...       Yes          1
# 6084  It's 83ï¿½_ï¿½ and climbing in NYC. August wea...       Yes          1
# 6085  @bloodless_coup "The phrase 'global warming' s...       Yes          1
#
#       other1  other2  other3
# 6080     NaN     NaN     NaN
# 6081     NaN     NaN     NaN
# 6082     NaN     NaN     NaN
# 6084     NaN     NaN     NaN
# 6085     NaN     NaN     NaN

# %%
d1=pd.concat([y1,n1])
df=pd.concat([d1,n2])

# %%
def word_cloud(words):
    stopwords = set(STOPWORDS)
    wordcloud = wcl(max_words=204,width = 603, height = 603,background_color ='black', stopwords = stopwords, 
                min_font_size = 10).generate(words) 
  
    plt.figure(figsize = (9, 9), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# %%
def extract_words(tweets):
    distinct_words = ' ' 
    for tweet in tweets: 
        tweet = str(tweet)
        tokens = tweet.split() 
        for i in range(len(tokens)): 
            tokens[i] = tokens[i].lower() 
        for words in tokens: 
            distinct_words = distinct_words + words + ' '
    return distinct_words

# %%
unique_wrds = extract_words(df.tweet)

# %%
word_cloud(unique_wrds)
